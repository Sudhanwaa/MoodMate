# %% [markdown]
# NOTE: The commented code blocks are only supposed to be run once and were made for my convinience. Hence Please do not run it else the dataset would be messed up.
# THANKYOU !

# %%
import pandas as pd
import os
import librosa
import numpy as np
import soundfile as sf
import random
import matplotlib.pyplot as plt
import IPython.display as ipd
import shutil

# %%
# labels=["angry","disgust","fear","happy","neutral","sad","surprise"]

# %% [markdown]
# Renaming files in each category (Only needed once)

# %%
# orig_path="D:/Projects/MoodMate/speech_dataset"
# categories=os.listdir(orig_path)

# for i in categories:
#     path=""
#     count=1
#     path=orig_path + "/" + i
#     samples=os.listdir(path)
#     for j in samples:
#         path=orig_path + "/" + i
#         new_path=""
#         new_path=path + "/" + i + "_" + str(count) + ".wav"
#         path=path + "/" + j
#         os.rename(path,new_path)
#         count+=1

# %% [markdown]
# Code to augment the sound data

# %%
signal1,sr1 = librosa.load("sudi.wav")
signal2,sr2 = librosa.load("output.wav")
plt.figure(figsize=(12, 4))
plt.plot(signal1)

plt.figure(figsize=(12, 4))
plt.plot(signal2)

# %%
signal1,sr1 = librosa.load("anger.wav")
ipd.Audio("sudi.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Segregating RAVDESS dataset into seperate categories
# ![image.png](attachment:image-2.png)

# %% [markdown]
# WARNING: Do this only if you have new data else the data will be duplicated with different name

# %%
# # Segregating the Audio files by their respective categories

# 01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised

# path="D:/Projects/MoodMate/RAVDESS"
# target_path="D:/Projects/MoodMate/speech_dataset"
# split_list=[]

# for actor in os.listdir(path):
#     for aud in os.listdir(path +"/" + actor):
#         split_list=aud.split("-")
#         emo=split_list[2]
#         if emo=="01":
#             emo_type="neutral"
#             # folder_length=len(os.listdir(target_path + "/" + emo_type))
#             shutil.copy(path + "/" + actor+ "/"+ aud , target_path+ "/" + emo_type)
            
#         if emo=="02":
#             continue
        
#         if emo=="03":
#             emo_type="happy"
#             shutil.copy(path + "/" + actor+ "/"+ aud , target_path+ "/" + emo_type)
            
#         if emo=="04":
#             emo_type="sad"
#             shutil.copy(path + "/" + actor+ "/"+ aud , target_path+ "/" + emo_type)
        
#         if emo=="05":
#             emo_type="angry"
#             shutil.copy(path + "/" + actor+ "/"+ aud , target_path+ "/" + emo_type)
            
#         if emo=="06":
#             emo_type="fear"
#             shutil.copy(path + "/" + actor+ "/"+ aud , target_path+ "/" + emo_type)
            
#         if emo=="07":
#             emo_type="disgust"
#             shutil.copy(path + "/" + actor+ "/"+ aud , target_path+ "/" + emo_type)
            
#         if emo=="08":
#             emo_type="surprise"
#             shutil.copy(path + "/" + actor+ "/"+ aud , target_path+ "/" + emo_type)
            
# # Renaming the Segregated Audio Files

# path="D:/Projects/MoodMate/RAVDESS"
# target_path="D:/Projects/MoodMate/speech_dataset"

# for emotion in os.listdir(target_path):
#     count=len(os.listdir(target_path + "/" + emotion)) +1  # We  put +1 so that the last filein the directoory doesnt get renamed
    
#     for audio in os.listdir(target_path+ "/" + emotion):
#         try:
#             os.rename(target_path+ "/" + emotion + "/" +audio ,target_path+ "/" + emotion + "/" + emotion + "_"+ str(count)+ ".wav")
#             count+=1
#         except:
#             pass

# %% [markdown]
# Code to delete content from files
# WARNING: Do this only agar koi galti hui hogi. Else all the data will be deleted

# %%
# path="D:/Projects/MoodMate/RAVDESS"
# target_path="D:/Projects/MoodMate/RAVDESS_seg"

# for emotion in os.listdir(target_path):
#     for i in os.listdir(target_path + "/" + emotion):
#         os.remove(target_path + "/" + emotion + "/" +i)

# %% [markdown]
# Renaming the audios in the dataset directory if the named numbers arent in the proper order.

# %%
# path= "D:/Projects/MoodMate/speech_dataset"

# for mood in os.listdir(path):
#     count =1
#     for audio in os.listdir(path + "/" + mood):
#         try:
#             os.rename(path+ "/" + mood + "/" +audio ,path+ "/" + mood + "/" + mood + "_"+ str(count)+ ".wav")
#             count+=1
#         except:
#             pass

# %% [markdown]
# Sound data augmentation

# %%
def white_noiser(signal,noise_factor): #0.3
        noise = np.random.normal(0,signal.std(),signal.size)
        augmented_signal = signal + noise * noise_factor
        return augmented_signal

def invert_polarity(signal):
        return signal * -1.5

def random_gain(signal,min_gain=0.15,max_gain=1.7):
        gain_factor = random.uniform(min_gain,max_gain)
        return signal*gain_factor       

def time_stretch(signal,speed):
        shifted_audio = librosa.effects.time_stretch(signal, speed)
        return shifted_audio

# %% [markdown]
# Code For calling the augmenting functions and saving the audio files in the respective directories

# %%
path="D:/Projects/MoodMate/speech_dataset"
    
for emotion in os.listdir(path):
    count=len(os.listdir(path + "/" + emotion)) +1
    
    for audio in os.listdir(path + "/" + emotion):
        signal,sr = librosa.load(path + "/" + emotion+"/"+ audio)
        
        augmented_signal_1=white_noiser(signal,round(random.uniform(0.1,0.34),2))
        sf.write(path + "/" + emotion + "/"+ emotion + "_" + str(count) + ".wav" ,augmented_signal_1,sr)
        count+=1
        
        augmented_signal_2=invert_polarity(signal)
        sf.write(path + "/" + emotion + "/"+ emotion + "_" + str(count) + ".wav" ,augmented_signal_2,sr)
        count+=1
        
        augmented_signal_3 = random_gain(signal)
        sf.write(path + "/" + emotion + "/"+ emotion + "_" + str(count) + ".wav" ,augmented_signal_3,sr)
        count+=1
        
        augmented_signal_4=time_stretch(signal,round(random.uniform(0.6,2),2))
        sf.write(path + "/" + emotion + "/"+ emotion + "_" + str(count) + ".wav",augmented_signal_4,sr)
        count+=1
# Out:
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.39 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.82 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.64 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.14 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.9 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.15 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.56 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.3 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.89 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.91 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.99 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.88 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.67 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.53 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.24 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.99 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.79 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.21 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.98 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.88 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.46 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.69 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.92 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.97 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.66 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.85 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.95 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.93 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.43 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.01 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.93 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.47 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.63 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.6 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.75 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.75 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.26 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.83 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.58 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.73 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.96 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.11 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.92 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.08 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.04 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.09 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.81 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.27 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.06 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.86 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.61 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.19 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.16 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.55 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.18 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.81 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.96 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.62 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.89 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.0 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.59 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.36 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.64 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.77 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.05 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.94 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.13 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.17 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.41 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.2 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.87 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.8 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.69 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.6 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.77 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.95 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.78 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.76 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.61 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.85 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.03 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=2.0 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.44 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.4 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.97 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.25 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.7 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.48 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.68 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.79 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.33 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.74 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.76 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.49 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.5 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.98 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.28 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.84 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.82 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.7 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.52 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.45 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.02 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.72 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.71 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.78 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.12 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.67 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.23 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.31 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.86 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.1 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.37 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.22 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.38 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.66 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.63 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.65 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.07 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.83 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.71 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.73 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.34 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.54 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.68 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.72 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.51 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.29 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.62 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.91 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.57 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.32 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.94 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.35 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.74 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.9 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.84 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.65 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.42 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=0.8 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#
# c:\Users\sudha\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Pass rate=1.87 as keyword args. From version 0.10 passing these as positional arguments will result in an error
